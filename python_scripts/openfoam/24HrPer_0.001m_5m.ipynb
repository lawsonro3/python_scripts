# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from glob import glob
from importlib import reload
import sowfa_precursor
sowfa_precursor = reload(sowfa_precursor)
# %matplotlib inline

# %% [markdown]
# # Creat sowfa_precursor object and enter neccisary user inputs

# %%
infPer_001m_5m =  sowfa_precursor.Sim(
    dir='/Users/mlawson/Peregrine/windsim/wake_steering/stableABLRuns/24HrPer_0.001m_5m',
    log='log.2.ABLSolver',
    time_dir='20000',
    avg_time=29000,
    avg_width=2000,
    z_level=90.0)
# Out:
# Read SOWFA "setUp" file:
# 	/Users/mlawson/Peregrine/windsim/wake_steering/stableABLRuns/24HrPer_0.001m_5m/setUp
# Set uStarMean = 0.351073757504 from SOWFA ".log" file:
# 	/Users/mlawson/Peregrine/windsim/wake_steering/stableABLRuns/24HrPer_0.001m_5m/log.2.ABLSolver

# %% [markdown]
# ## Enter heights to do stuff... ;)

# %%
infPer_001m_5m.input['heights'] = np.array([0,1/2,1,3/2,2,3,4,5])*infPer_001m_5m.input['windHeight']

# %% [markdown]
# ## Make Plots

# %%
infPer_001m_5m.theta_w_avg_cell()
# Out:
# Time from  28000.0 to  29999.404127099995

# %%
infPer_001m_5m.Umean_avg_nonnormalized()

# %%
infPer_001m_5m.Tmean_avg_nonnormalized()

# %%
infPer_001m_5m.variances_avg_cell()
